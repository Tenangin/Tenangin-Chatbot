# %%
import pandas as pd
data_articles = pd.read_csv('Data/scraped_articles.csv')

# %%
filtered_data = data_articles[data_articles['content'].str.contains('pijar psikologi', case=False, na=False)]
data_articles = data_articles.drop(filtered_data.index)
data_articles
# Out:
#                                                  title  \
# 0                      Resensi : How to Respect Myself
# 1            Merasa Bahagia dengan Decluttering Barang
# 2        Pekerja Media Kreatif Juga Harus Sehat Mental
# 3    Being Here and Now : Sebuah Ikhtiar Diri di Te...
# 4                     Pahit dan Sakit Sebuah Kegagalan
# ..                                                 ...
# 682  Autisme: Malaikat Juga Tahu – Ketulusan Cinta ...
# 683              Kemampuan Luar Biasa di Balik Autisme
# 684         Anak-anak dengan Autisme pun bisa mandiri!
# 685            Menghadapi Anak dengan Retardasi Mental
# 686                 Bipolar: Mereka pun Dapat Bersinar
#
#                                                content
# 0    Judul Buku : How to Respect Myself\nPengarang ...
# 1                Saat ini, membeli barang secara on...
# 2    “Bagaimana cara mengatasi stres pada pekerja s...
# 3    Mental illness atau yang biasa dikenal dengan ...
# 4    Kegagalan adalah proses manusiawi. Proses ters...
# ..                                                 ...
# 682  Malaikat Juga Tahu adalah salah satu dari lima...
# 683  National Autism Association melakukan riset pa...
# 684  “Biarkan mereka mewarnai dunia mereka dengan w...
# 685  Anak dengan retardasi mental seringkali diangg...
# 686  Seorang penyanyi cantik yang juga aktris asal ...
#
# [522 rows x 2 columns]

# %%
# Specify the column to save
column_name = 'content'  # Replace with the actual column name

# Save the column content to a text file
data_articles[column_name].to_csv("dokumen3.txt", index=False, header=False, encoding='utf-8')

# %%
file_paths = {
    'dokumen1': 'Data/dokumen1_almost_clean.txt',
    'dokumen2': 'Data/dokumen2_almost_clean.txt',
    'dokumen3': 'Data/dokumen3.txt',
    'dokumen4': 'Data/dokumen4.txt'
}

docs = {}
for doc_name, path in file_paths.items():
    with open(path, 'r', encoding='utf-8') as file:
        docs[doc_name] = file.read()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate word clouds for all documents in the docs dictionary
for doc_name, doc_content in docs.items():
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(doc_content)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Word Cloud for {doc_name.capitalize()}')
    plt.show()

# %% [markdown]
# # Preprocessing

# %%
import re

def preprocess_text(text: str) -> str:
    # 1. Ganti dua atau lebih newline dengan token sementara agar tidak terganti
    text = re.sub(r'\n{2,}', '[PARA_BREAK]', text)

    # 2. Ganti newline tunggal dengan spasi
    text = text.replace('\n', ' ')

    # 3. Kembalikan token [PARA_BREAK] ke dua newline
    text = text.replace('[PARA_BREAK]', '\n\n')

    # 4. Hapus spasi ganda
    text = re.sub(r' +', ' ', text)

    text = re.sub(r'\bFF\b', '', text)

    # 5. Hapus spasi di awal/akhir teks
    text = text.strip()

    return text

# %%
for _,doc in docs.items():
    cleaned_doc = preprocess_text(doc)
    with open(f'Data/cleaned_{_}.txt', 'w', encoding='utf-8') as file:
        file.write(cleaned_doc)

# %%
file_path1 = 'Data/cleaned_dokumen1.txt'
file_path2 = 'Data/cleaned_dokumen1.txt'

with open(file_path1, 'r', encoding='utf-8') as file:
    dokumen1 = file.read()

with open(file_path2, 'r', encoding='utf-8') as file:
    dokumen2 = file.read()

docs_clean = {
    'dokumen1': dokumen1,
    'dokumen2': dokumen2
}

# %%
docs['dokumen1']
# Out:
# 'Kesehatan mental memiliki pengertian keadaan dimana\nperkembangan fisik, intelektual dan emosional pada diri\nseseorang tumbuh, berkembang dan matang pada\nkehidupannya, menerima tanggung jawab, menemukan\npenyesuaian, memelihara aturan sosial dan tindakan dalam\nbudayanya. Kesehatan mental berasal dari bahasa Inggris, yaitu\nmental hygiene. Mental berasal dari kata latin mens, mentis yang\nberarti jiwa, nyawa, sukma, roh, dan semangat. Sedangkan\nhygiene berasal dari kata yunani hygiene yang berarti ilmu\ntentang Kesehatan (Ardiansyah et al., 2023).\nMenurut Federasi Kesehatan Mental Dunia (World\nFederation for Mental Health), kesehatan mental adalah (1)\nkondisi yang memungkinkan adanya perkembangan yang\noptimal baik secara fisik, intelektual dan emosional, sepanjang\nhal itu sesuai dengan keadaan orang lain, dan (2) sebuah\nmasyarakat yang baik adalah masyarakat yang membolehkan\nperkembangan ini pada anggota masyarakatnya selain pada saat\nyang sama menjamin dirinya berkembang dan toleran terhadap\nmasyarakat yang lain. Definisi kesehatan mental menurut WHO\nadalah kondisi kesejahteraan (well-being) seorang individu yang\nmenyadari kemampuannya sendiri, dapat mengatasi tekanan\nkehidupan yang normal, dapat bekerja secara produktif dan\n\nKesehatan mental merupakan dimensi kesehatan yang\nmendasar, memainkan peran penting dalam membentuk\nkualitas hidup dan keberhasilan individu. Kesehatan mental\ntidak sekadar mengacu pada ketiadaan gangguan mental,\nmelainkan mencakup keseimbangan emosional, kemampuan\nmengelola stres, dan daya tahan terhadap tekanan kehidupan.\nKesehatan mental adalah keadaan kesehatan yang\nmelibatkan\nkesejahteraan\nemosional,\npsikologis,\ndan\nsosialseseorang. Ini mencakup kemampuan individu untuk\nmengatasi stres, membangun hubungan yang sehat, membuat\nkeputusan yang tepat, serta merasakan dan mengelola emosi\ndengan baik. Kesehatan mental tidak hanya berkaitan dengan\nketiadaan gangguan mental, tetapi juga melibatkan kemampuan\nuntuk berfungsi secara optimal dalam kehidupan sehari-hari.\n(Durand V., Barlow D, 2006)\nDalam beberapa dekade terakhir, stigma yang melingkupi\nkesehatan mental masih menjadi hambatan utama dalam upaya\nmenciptakan masyarakat yang mendukung aspek ini. Prejudice\ndan ketidakpahaman terhadap tantangan kesehatan mental\nseringkali menyebabkan individu enggan untuk mencari\npertolongan atau bahkan membicarakan pengalaman mereka.\n\n\nKesehatan merupakan kebutuhan utama bagi semua\nmakhluk hidup, khususnya manusia, dalam mencapai tujuan\nhidupnya. Dari segi fisik, setiap individu menginginkan\nkesehatan tubuhnya yang optimal. Selain itu, secara psikologis,\npenting bagi manusia untuk merawat kesehatan mental atau\njiwa mereka. Oleh karena itu, kesehatan dianggap sebagai nilai\nyang sangat berharga, yang selalu diperjuangkan oleh setiap\nindividu, meskipun memerlukan pengorbanan dan biaya yang\ntinggi. Hal ini menunjukkan bahwa kesehatan menjadi tolak\nukur keberhasilan mencapai kebahagiaan yang sejati. Dengan\ndemikian, menjadi sehat berarti menjadi salah satu aspek kunci\ndalam mencapai kehidupan yang bahagia, dalam arti yang luas.\nKetika seseorang mengalami penyakit atau kesehatan yang\nburuk, kenikmatan hidup secara perlahan akan menghilang dan\ndigantikan oleh penderitaan yang berkepanjangan. Sebaliknya,\njika penyakit dapat diatasi, rasa bahagia secara bertahap akan\ndiraih kembali.\nKesehatan mental memiliki sejarah yang kaya dan\npanjang dan telah dikenal sejak berabad-abad lalu. Hal itu\nmemberikan perjalanan yang menarik mulai dari Yunani kuno\nhingga kompleksitas abad ke-21. di masa Yunani kuno,\nkesehatan mental seringkali terkait dengan keyakinan filosofis\n\n\nSehat dan sakit adalah keadaan biopsikososial yang\nmenyatu dengan kehidupan manusia. Pengenalan manusia\nterhadap kedua konsep ini bisa bersamaan dengan\npengenalannya terhadap kondisi dirinya. Keadaan sehat dan\nsakit tersebut terus terjadi, dan manusia akan memerankan\nsebagai orang yang sehat atau sa ...
